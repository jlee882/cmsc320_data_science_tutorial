# %% [markdown]
# # Title
#
# Bike share programs are a type of shared public transporatation system that is considered to be eco-friendly and sustainable. Typically these systems work by allowing people to rent bikes at a station, travel to their destination, and return the bike to another station. Such bike programs are frequently implemented in more densly populated areas such as cities, and have been relatively successful. Majority of revenue is from bike users and the time they borrow a bike. This leads to the question: what factors influences the number of bike trips? Knowing this can allow us to see what business strategies can be used to optimize the conditions in which people use bike share programs and potentially incentivize people to use these more.

# %%
import sqlite3
import pandas as pd
import folium

# %% [markdown]
# ## Importing Data
# To analyze this, we can first obtain some sample data from a bike share program

# %%
# tables are [('station',), ('status',), ('trip',), ('weather',)]
con = sqlite3.connect("database.sqlite")

# get tables
sql_query = "SELECT name FROM sqlite_master WHERE type='table';"
cursor = con.cursor()
cursor.execute(sql_query)
print(cursor.fetchall())
# Out:
# [('station',), ('status',), ('trip',), ('weather',)]

# %%
station = pd.read_sql_query("SELECT * from station", con)
#status = pd.read_sql_query("SELECT * from status", con)
trip = pd.read_sql_query("SELECT * from trip", con)
weather = pd.read_sql_query("SELECT * from weather", con)

# %%
# Columns in each table
station # id, name, lat, long, dock_count, city, installation_date
#status # station_id, bikes_available, docks_available, time
trip 
"""(['id', 'duration', 'start_date', 'start_station_name',
       'start_station_id', 'end_date', 'end_station_name', 'end_station_id',
       'bike_id', 'subscription_type', 'zip_code'],
      dtype='object')"""
weather 
""" (['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f',
       'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f',
       'max_humidity', 'mean_humidity', 'min_humidity',
       'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches',
       'min_sea_level_pressure_inches', 'max_visibility_miles',
       'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph',
       'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches',
       'cloud_cover', 'events', 'wind_dir_degrees', 'zip_code'],
      dtype='object')"""

trip
# Out:
#             id  duration       start_date  \
# 0         4069       174   8/29/2013 9:08
# 1         4073      1067   8/29/2013 9:24
# 2         4074      1131   8/29/2013 9:24
# 3         4075      1117   8/29/2013 9:24
# 4         4076      1118   8/29/2013 9:25
# ...        ...       ...              ...
# 669954  913453       789  8/31/2015 23:09
# 669955  913454       409  8/31/2015 23:10
# 669956  913455       307  8/31/2015 23:13
# 669957  913459      1036  8/31/2015 23:11
# 669958  913460       765  8/31/2015 23:26
#
#                           start_station_name  start_station_id  \
# 0                          2nd at South Park                64
# 1                   South Van Ness at Market                66
# 2                   South Van Ness at Market                66
# 3                   South Van Ness at Market                66
# 4                   South Van Ness at Market                66
# ...                                      ...               ...
# 669954                 Embarcadero at Folsom                51
# 669955                    San Jose City Hall                10
# 669956                        Post at Kearny                47
# 669957           San Antonio Shopping Center                31
# 669958  Harry Bridges Plaza (Ferry Building)                50
#
#                end_date                          end_station_name  \
# 0        8/29/2013 9:11                         2nd at South Park
# 1        8/29/2013 9:42   San Francisco Caltrain 2 (330 Townsend)
# 2        8/29/2013 9:43   San Francisco Caltrain 2 (330 Townsend)
# 3        8/29/2013 9:43   San Francisco Caltrain 2 (330 Townsend)
# 4        8/29/2013 9:43   San Francisco Caltrain 2 (330 Townsend)
# ...                 ...                                       ...
# 669954  8/31/2015 23:22                    Embarcadero at Sansome
# 669955  8/31/2015 23:17                       San Salvador at 1st
# 669956  8/31/2015 23:18                         2nd at South Park
# 669957  8/31/2015 23:28                   Mountain View City Hall
# 669958  8/31/2015 23:39  San Francisco Caltrain (Townsend at 4th)
#
#         end_station_id  bike_id subscription_type zip_code
# 0                   64      288        Subscriber    94114
# 1                   69      321        Subscriber    94703
# 2                   69      317        Subscriber    94115
# 3                   69      316        Subscriber    94122
# 4                   69      322        Subscriber    94597
# ...                ...      ...               ...      ...
# 669954              60      487          Customer     9069
# 669955               8       68        Subscriber    95113
# 669956              64      468        Subscriber    94107
# 669957              27       35        Subscriber    95032
# 669958              70      288        Subscriber     2139
#
# [669959 rows x 11 columns]

# %% [markdown]
# ## Data Cleaning and Manipulation (reword me)

# %%
# mark all the stations
map_osm = folium.Map(location=[37.60, -122.29], zoom_start=10)

for index, station_info in station.iterrows():
    tooltip_text = station_info['name'] + "\n"
    folium.Marker(location=[station_info["lat"], station_info["long"]], tooltip=tooltip_text).add_to(map_osm)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a9d3dad2a257fcd1908bf89bb5c9fa3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a9d3dad2a257fcd1908bf89bb5c9fa3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a9d3dad2a257fcd1908bf89bb5c9fa3 = L.map(
#                 &quot;map_7a9d3dad2a257fcd1908bf89bb5c9fa3&quot;,
#                 {
#                     center: [37.6, -122.29],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b36dbca3a489a1766c057219ba5e11f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             var marker_73338cad97a75654e6be66b4a644b461 = L.marker(
#                 [37.329732, -121.90178200000001],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_73338cad97a75654e6be66b4a644b461.bindTooltip(
#                 `&lt;div&gt;
#                      San Jose Diridon Caltrain Station
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_21323fb27b1a3ae47f31614afc7add15 = L.marker(
#                 [37.330698, -121.888979],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_21323fb27b1a3ae47f31614afc7add15.bindTooltip(
#                 `&lt;div&gt;
#                      San Jose Civic Center
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40527a61c835a38af0ea5ace61797c52 = L.marker(
#                 [37.333988, -121.894902],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_40527a61c835a38af0ea5ace61797c52.bindTooltip(
#                 `&lt;div&gt;
#                      Santa Clara at Almaden
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40ea44d8d848a7edad9be6a682197443 = L.marker(
#                 [37.331415, -121.8932],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_40ea44d8d848a7edad9be6a682197443.bindTooltip(
#                 `&lt;div&gt;
#                      Adobe on Almaden
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_263409b666413e7917ad2bd9c938885a = L.marker(
#                 [37.336721000000004, -121.894074],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_263409b666413e7917ad2bd9c938885a.bindTooltip(
#                 `&lt;div&gt;
#                      San Pedro Square
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b6f27d537f179a968d98c26164e64cad = L.marker(
#                 [37.333798, -121.88694299999999],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_b6f27d537f179a968d98c26164e64cad.bindTooltip(
#                 `&lt;div&gt;
#                      Paseo de San Antonio
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e86014aeed5a82ef4fa536cbcf430bd = L.marker(
#                 [37.330165, -121.88583100000001],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_5e86014aeed5a82ef4fa536cbcf430bd.bindTooltip(
#                 `&lt;div&gt;
#                      San Salvador at 1st
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5969528b1958cf04d43c6cf33c074fa2 = L.marker(
#                 [37.348742, -121.89471499999999],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_5969528b1958cf04d43c6cf33c074fa2.bindTooltip(
#                 `&lt;div&gt;
#                      Japantown
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_429cbc0ec15b0fe35a1e874b5950c881 = L.marker(
#                 [37.337391, -121.886995],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3);
#
#
#             marker_429cbc0ec15b0fe35a1e874b5950c881.bindTooltip(
#                 `&lt;div&gt;
#                      San Jose City Hall
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f849de68df44bff1dd2214a9a31e71e1 = L.marker(
#                 [37.335885, -121.88566000000002],
#                 {}
#             ).addTo(map_7a9d3dad2a257fcd1908bf89bb5c9fa3

# %%
# Convert time from object to datetime
trip["date"] = pd.to_datetime(trip["start_date"]).dt.date
trip.head()

# %% [markdown]
# ## Data Exploration

# %%
trips_by_date = trip.groupby(["date"])

start_trips_by_date = []
end_trips_by_date = []

for index, group in trips_by_date:
    trips_per_start_station = group.groupby("start_station_id")
    start_trips_by_date.append(trips_per_start_station["id"].count())
    
    #trips_per_end_station = group.groupby("end_station_id")
    #end_trips_by_date.append(trips_per_end_station["id"].count())
# Out:
# date
# 2013-08-29     748
# 2013-08-30     714
# 2013-08-31     640
# 2013-09-01     706
# 2013-09-02     661
#               ...
# 2015-08-27    1443
# 2015-08-28    1220
# 2015-08-29     342
# 2015-08-30     331
# 2015-08-31    1369
# Length: 733, dtype: int64

# %% [markdown]
# ## Data Analysis and Hypothesis Testing

# %%
trips = trips_by_date.size()
weather
# Out:
#            date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0     8/29/2013               74.0                68.0               61.0
# 1     8/30/2013               78.0                69.0               60.0
# 2     8/31/2013               71.0                64.0               57.0
# 3      9/1/2013               74.0                66.0               58.0
# 4      9/2/2013               75.0                69.0               62.0
# ...         ...                ...                 ...                ...
# 3660  8/27/2015               92.0                78.0               63.0
# 3661  8/28/2015               95.0                80.0               64.0
# 3662  8/29/2015               80.0                72.0               64.0
# 3663  8/30/2015               78.0                70.0               62.0
# 3664  8/31/2015               85.0                72.0               59.0
#
#       max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0                61.0              58.0             56.0          93.0
# 1                61.0              58.0             56.0          90.0
# 2                57.0              56.0             54.0          93.0
# 3                60.0              56.0             53.0          87.0
# 4                61.0              60.0             58.0          93.0
# ...               ...               ...              ...           ...
# 3660             57.0              51.0             40.0          78.0
# 3661             64.0              56.0             52.0          93.0
# 3662             65.0              62.0             54.0          93.0
# 3663             60.0              57.0             53.0          84.0
# 3664             59.0              55.0             51.0          84.0
#
#       mean_humidity  min_humidity  ...  mean_visibility_miles  \
# 0              75.0          57.0  ...                   10.0
# 1              70.0          50.0  ...                   10.0
# 2              75.0          57.0  ...                   10.0
# 3              68.0          49.0  ...                   10.0
# 4              77.0          61.0  ...                   10.0
# ...             ...           ...  ...                    ...
# 3660           48.0          18.0  ...                   10.0
# 3661           60.0          26.0  ...                   10.0
# 3662           70.0          47.0  ...                   10.0
# 3663           64.0          43.0  ...                   10.0
# 3664           58.0          32.0  ...                   10.0
#
#       min_visibility_miles  max_wind_Speed_mph  mean_wind_speed_mph  \
# 0                     10.0                23.0                 11.0
# 1                      7.0                29.0                 13.0
# 2                     10.0                26.0                 15.0
# 3                     10.0                25.0                 13.0
# 4                      6.0                23.0                 12.0
# ...                    ...                 ...                  ...
# 3660                  10.0                23.0                  6.0
# 3661                  10.0                25.0                  7.0
# 3662                  10.0                21.0                  9.0
# 3663                  10.0                22.0                 10.0
# 3664                  10.0                20.0                  6.0
#
#       max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                   28.0                     0          4.0
# 1                   35.0                     0          2.0
# 2                   31.0                     0          4.0
# 3                   29.0                     0          4.0
# 4                   30.0                     0          6.0
# ...                  ...                   ...          ...     ...
# 3660                29.0                     0          3.0
# 3661                30.0                     0          3.0
# 3662                26.0                     0          4.0
# 3663                29.0                     0          3.0
# 3664                24.0                     0          1.0
#
#       wind_dir_degrees zip_code
# 0                286.0    94107
# 1                291.0    94107
# 2                284.0    94107
# 3                284.0    94107
# 4                277.0    94107
# ...                ...      ...
# 3660             313.0    95113
# 3661             307.0    95113
# 3662             312.0    95113
# 3663             291.0    95113
# 3664             308.0    95113
#
# [3665 rows x 24 columns]

# %% [markdown]
# ## Predicting [something] with Machine Learning

# %%
# Data cleaning

weather = weather.apply(pd.to_numeric, errors='ignore')

weather_by_date = weather.groupby("date")
for index, group in weather_by_date:
    pass
weather_by_date.mean()
# Out:
#            max_temperature_f  mean_temperature_f  min_temperature_f  \
# date
# 1/1/2014                58.2                47.8               37.0
# 1/1/2015                55.0                44.6               34.0
# 1/10/2014               61.6                52.0               42.8
# 1/10/2015               59.8                53.8               47.4
# 1/11/2014               58.4                50.8               44.0
# ...                      ...                 ...                ...
# 9/7/2014                72.8                65.8               58.8
# 9/8/2013                81.6                70.0               59.4
# 9/8/2014                68.8                63.2               57.4
# 9/9/2013                83.8                71.4               59.4
# 9/9/2014                74.0                65.2               55.8
#
#            max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# date
# 1/1/2014              42.4              36.8             32.8          86.0
# 1/1/2015              29.6              24.0             17.8          65.6
# 1/10/2014             49.0              43.6             38.0          88.8
# 1/10/2015             52.0              48.6             45.6          97.2
# 1/11/2014             50.0              44.4             40.0          91.6
# ...                    ...               ...              ...           ...
# 9/7/2014              56.4              54.4             51.6          84.0
# 9/8/2013              60.8              56.8             52.2          85.8
# 9/8/2014              54.2              52.2             50.8          80.4
# 9/9/2013              61.4              57.2             51.6          87.2
# 9/9/2014              58.0              54.2             51.2          88.6
#
#            mean_humidity  min_humidity  max_sea_level_pressure_inches  ...  \
# date                                                                   ...
# 1/1/2014            69.0          48.0                         30.224  ...
# 1/1/2015            45.4          25.2                         30.182  ...
# 1/10/2014           74.2          56.8                         30.316  ...
# 1/10/2015           84.8          69.0                         30.054  ...
# 1/11/2014           80.8          68.4                         30.302  ...
# ...                  ...           ...                            ...  ...
# 9/7/2014            70.4          54.4                         29.922  ...
# 9/8/2013            66.8          41.8                         29.884  ...
# 9/8/2014            68.8          55.0                         29.956  ...
# 9/9/2013            67.6          37.6                         29.824  ...
# 9/9/2014            72.6          54.0                         30.012  ...
#
#            min_sea_level_pressure_inches  max_visibility_miles  \
# date
# 1/1/2014                          30.128                  10.0
# 1/1/2015                          30.084                  10.0
# 1/10/2014                         30.186                  10.0
# 1/10/2015                         29.960                  10.0
# 1/11/2014                         30.168                  10.0
# ...                                  ...                   ...
# 9/7/2014                          29.812                  11.0
# 9/8/2013                          29.758                  10.0
# 9/8/2014                          29.860                  11.0
# 9/9/2013                          29.716                  10.0
# 9/9/2014                          29.908                  10.0
#
#            mean_visibility_miles  min_visibility_miles  max_wind_Speed_mph  \
# date
# 1/1/2014                     8.2                   5.8                 9.0
# 1/1/2015                    10.0                  10.0                12.0
# 1/10/2014                    9.8                   7.8                10.8
# 1/10/2015                    7.4                   4.2                 8.2
# 1/11/2014                    9.8                   7.6                16.2
# ...                          ...                   ...                 ...
# 9/7/2014                    10.0                   8.6                16.4
# 9/8/2013                    10.0                  10.0                13.2
# 9/8/2014                    10.0                   9.2                18.4
# 9/9/2013                    10.0                  10.0                15.2
# 9/9/2014                     9.8                   8.4                13.8
#
#            mean_wind_speed_mph  max_gust_speed_mph  cloud_cover  \
# date
# 1/1/2014                   1.0           11.500000          1.2
# 1/1/2015                   3.8           18.000000          0.4
# 1/10/2014                  2.6           14.000000          2.6
# 1/10/2015                  3.0            9.333333          4.2
# 1/11/2014                  2.8           21.500000          3.6
# ...                        ...                 ...          ...
# 9/7/2014                   7.4           22.333333          3.4
# 9/8/2013                   4.6           17.750000          0.8
# 9/8/2014                   8.8           21.500000          3.6
# 9/9/2013                   4.6           20.250000          0.4
# 9/9/2014                   5.0           17.666667          3.2
#
#            wind_dir_degrees  zip_code
# date
# 1/1/2014              270.0   94325.0
# 1/1/2015              228.2   94325.0
# 1/10/2014             329.8   94325.0
# 1/10/2015             309.8   94325.0
# 1/11/2014             284.2   94325.0
# ...                     ...       ...
# 9/7/2014              317.8   94325.0
# 9/8/2013              320.4   94325.0
# 9/8/2014              312.0   94325.0
# 9/9/2013              321.0   94325.0
# 9/9/2014              315.8   94325.0
#
# [733 rows x 21 columns]

# %% [markdown]
# ## Conclusion
